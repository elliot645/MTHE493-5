# %%
import pandas as pd

# %%
db = pd.read_csv('C:/Users/ellio/python/MTHE493-5/data/us_county_population_estimates_by_age_2020_to_2023.csv', encoding='latin1')

db.head(10)
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  POPESTIMATE  \
# 0      50      1       1  Alabama  Autauga County     1        58809
# 1      50      1       1  Alabama  Autauga County     2        58915
# 2      50      1       1  Alabama  Autauga County     3        59203
# 3      50      1       1  Alabama  Autauga County     4        59726
# 4      50      1       1  Alabama  Autauga County     5        60342
# 5      50      1       3  Alabama  Baldwin County     1       231768
# 6      50      1       3  Alabama  Baldwin County     2       233227
# 7      50      1       3  Alabama  Baldwin County     3       239439
# 8      50      1       3  Alabama  Baldwin County     4       246531
# 9      50      1       3  Alabama  Baldwin County     5       253507
#
#    POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 0        28698       30111        3491  ...         1053         1144
# ...

# %%
len(db[db['YEAR'] == 5])
# Out:
# 3144

# %%
data = {}
for index, row in db.iterrows():
    year_dict = data.setdefault(row['YEAR'], {})
    state_dict = year_dict.setdefault(row['STNAME'], {})
    state_dict[row['CTYNAME']] = row['POPESTIMATE']

    year_dict[row['STNAME']] = state_dict
    data[row['YEAR']] = year_dict

# %%
data[5]['Alabama']
# Out:
# {'Autauga County': 60342,
#  'Baldwin County': 253507,
#  'Barbour County': 24585,
#  'Bibb County': 21868,
#  'Blount County': 59816,
#  'Bullock County': 9897,
#  'Butler County': 18382,
#  'Calhoun County': 116429,
#  'Chambers County': 34079,
#  'Cherokee County': 25666,
#  'Chilton County': 46431,
#  'Choctaw County': 12252,
#  'Clarke County': 22337,
#  'Clay County': 14111,
#  'Cleburne County': 15639,
#  'Coffee County': 55643,
#  'Colbert County': 58361,
#  'Conecuh County': 11174,
#  'Coosa County': 10268,
#  'Covington County': 37952,
#  'Crenshaw County': 13101,
#  'Cullman County': 92016,
#  'Dale County': 49871,
#  'Dallas County': 36165,
#  'DeKalb County': 72569,
#  'Elmore County': 90441,
#  'Escambia County': 36558,
#  'Etowah County': 103241,
#  'Fayette County': 15967,
#  'Franklin County': 31802,
#  'Geneva County': 26988,
#  'Greene County': 7341,
#  'Hale County': 14888,
#  'Henry County': 17899,
#  'Houston County': 108462,
#  'Jackson County': 53467,
# ...
